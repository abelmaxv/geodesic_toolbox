# %% [markdown]
# # Parameter tuning : Funnel distribution

# %%
import torch
from torch import Tensor
from geodesic_toolbox import ImplicitFHMCUnbiased, ImplicitRHMCSampler, FunnelDualRanders, FunnelSoftAbs, HMCSampler, IdentityCoMetric
import tqdm
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import time
import numpy as np

# %%
DIM = 30          # dimension of theta; state dim = DIM + 1 (v, theta_1 .. theta_DIM)
STATE_DIM = DIM + 1


class FunnelFHMCUnbiased(ImplicitFHMCUnbiased):
    def __init__(self, dim: int, l: int, N_fx: int, gamma: float, N_run: int,
                 bounds: float = 1e3, std_0: float = 1., beta_0: float = 1.,
                 pbar: bool = False, skip_acceptance: bool = False,
                 reduced_flip: bool = True, alpha: float = 10**6, beta : float = 1.):
        self.dim = dim
        randers_cometric = FunnelDualRanders(dim=dim, alpha=alpha, beta=beta)
        super().__init__(
            randers_cometric=randers_cometric,
            l=l, N_fx=N_fx, gamma=gamma, N_run=N_run,
            bounds=bounds, std_0=std_0, beta_0=beta_0,
            pbar=pbar, skip_acceptance=skip_acceptance,
            reduced_flip=reduced_flip,
        )

    def U(self, z):
        v = z[:, 0]
        theta = z[:, 1:]
        return v**2 / 18 + (self.dim / 2) * v + torch.exp(-v) / 2 * (theta**2).sum(dim=1)

    def K(self, p: Tensor, z: Tensor) -> Tensor:
        d   = z.shape[1]
        eps = self.randers_cometric.epsilon
        _, w_star, G_star = self.randers_cometric._shared(z)   # ONE eigh

        # F* without re-eigh
        v_norm = torch.einsum("bi,bij,bj->b", p, G_star, p).sqrt()
        F_star = v_norm + torch.einsum("bi,bi->b", w_star, p)
        F_star_sq = F_star ** 2 + eps ** 2     # avoid the throw-away outer sqrt

        # BH terms via one Cholesky of G* (G* is already in hand)
        L = torch.linalg.cholesky(G_star)
        y = torch.linalg.solve_triangular(L, w_star.unsqueeze(-1), upper=False).squeeze(-1)
        alpha = torch.einsum("bi,bi->b", y, y)
        logdet_G_star = 2.0 * torch.diagonal(L, dim1=-2, dim2=-1).log().sum(-1)

        return (0.5 * F_star_sq
                - 0.5 * (d + 1) * torch.log1p(-alpha)
                - 0.5 * logdet_G_star
                + 0.5 * d * self.log2pi)

    def H(self, z: Tensor, p: Tensor) -> Tensor:
        return self.U(z) + self.K(p, z)

    def H_tilde(self, z: Tensor, p: Tensor) -> Tensor:
        d   = z.shape[1]
        eps = self.randers_cometric.epsilon

        G_inv, w_star, G_star = self.randers_cometric._shared(z)   # ONE eigh

        L             = torch.linalg.cholesky(G_star)
        y             = torch.linalg.solve_triangular(
                            L, w_star.unsqueeze(-1), upper=False).squeeze(-1)
        b_sq          = torch.einsum("bi,bi->b", y, y)   # |omega*|^2_{G*^-1} = 1 - alpha_s
        alpha_s       = 1.0 - b_sq
        logdet_G_star = 2.0 * torch.diagonal(L, dim1=-2, dim2=-1).log().sum(-1)

        # BCS identity: det G . det G* = alpha_s^{-(d+1)}
        #   => 1/2(d+1) log alpha_s + 1/2 log det G = -1/2 log det G*
        log_sigma_BH  = -0.5 * logdet_G_star

        # momentum scalars, without materialising G*
        p_Ginv_p = torch.einsum("bi,bij,bj->b", p, G_inv, p)   # p^T G^{-1} p
        wstar_p  = torch.einsum("bi,bi->b", w_star, p)          # omega* . p

        # p^T G* p = (omega*.p)^2 + p^T G^{-1} p / alpha_s   (from the MDL form of G*)
        riem_norm = (wstar_p**2 + p_Ginv_p / alpha_s).sqrt()
        F_star_sq = (riem_norm + wstar_p)**2 + eps**2
        log_randers_factor = torch.log1p(wstar_p / riem_norm)

        return (
            self.U(z)
            + 0.5  * F_star_sq
            - (d + 1) * log_randers_factor
            + log_sigma_BH
            + 0.5 * d * self.log2pi
        )


class FunnelRHMC(ImplicitRHMCSampler):
    def __init__(self, dim: int, l: int, N_fx: int, gamma: float, N_run: int,
                 alpha: float = 1.0, bounds: float = 1e3, std_0: float = 1.,
                 beta_0: float = 1., pbar: bool = False, skip_acceptance: bool = False):
        self.dim = dim
        cometric = FunnelSoftAbs(dim=dim, alpha=alpha)
        super().__init__(
            cometric=cometric, l=l, N_fx=N_fx, gamma=gamma, N_run=N_run,
            bounds=bounds, std_0=std_0, beta_0=beta_0,
            pbar=pbar, skip_acceptance=skip_acceptance,
        )

    def U(self, z: Tensor) -> Tensor:
        v = z[:, 0]
        theta = z[:, 1:]
        return v**2 / 18 + (self.dim / 2) * v + torch.exp(-v) / 2 * (theta**2).sum(dim=1)


class FunnelHMC(HMCSampler):
    def __init__(self, dim: int, mass: float, l: int, gamma: float, N_run: int,
                 bounds: float = 1e3, std_0: float = 1., beta_0: float = 1.,
                 pbar: bool = False, skip_acceptance: bool = False):
        self.dim = dim
        super().__init__(
            cometric=IdentityCoMetric(coscale = mass, is_diag=False),
            l=l, gamma=gamma, N_run=N_run,
            bounds=bounds, std_0=std_0, beta_0=beta_0,
            pbar=pbar, skip_acceptance=skip_acceptance,
        )

    def U(self, z: Tensor) -> Tensor:
        v = z[:, 0]
        theta = z[:, 1:]
        return v**2 / 18 + (self.dim / 2) * v + torch.exp(-v) / 2 * (theta**2).sum(dim=1)

    def leapfrog_trajectory(self, z_0: Tensor) -> Tensor:
        v_0 = self.sample_momentum(z_0)
        traj_q, _ = self.leapfrog(z_0, v_0, return_traj=True)
        return traj_q   # (B, l+1, d)

# %% [markdown]
# ## Step 1 : Stability of $\gamma$

# %%
def eval_gamma1(gamma : float, method : str, N_run : int = 100, z_0 = torch.zeros(10, STATE_DIM), mass : float = 1) :
    if method == "HMC" :
        sampler = FunnelHMC(
            dim = DIM,
            mass = mass,
            l = 30, #l_rhmc*N_fx
            gamma = gamma,
            N_run = N_run
        )
    else :
        sampler = FunnelRHMC(
            dim = DIM,
            l = 5,
            N_fx = 6,
            gamma = gamma,
            N_run = N_run
        )
    _, acc = sampler.sample(z_0, return_acceptance=True)
    return acc

# %%
grid_res = 20
mass = 1
gamma_grid = torch.linspace(0.01, 0.3, grid_res)
HMC_eval1 = torch.zeros(grid_res)
RHMC_eval1 = torch.zeros(grid_res)

for i in tqdm.tqdm(range(grid_res)) :
    gamma = gamma_grid[i]
    eval_hmc = eval_gamma1(gamma, "HMC", mass = mass)
    eval_rhmc = eval_gamma1(gamma, "RHMC")
    HMC_eval1[i] = eval_hmc
    RHMC_eval1[i] = eval_rhmc
# Out:
# 100%|██████████| 20/20 [05:25<00:00, 16.26s/it]

# %%
fig, ax = plt.subplots(figsize=(7, 5))

ax.plot(gamma_grid, HMC_eval1, label="HMC", color="#1f77b4", linewidth=2, marker="o", markersize=4)
ax.plot(gamma_grid, RHMC_eval1, label="RHMC", color="#d62728", linewidth=2, marker="o", markersize=4)

ax.xaxis.set_major_locator(mticker.MultipleLocator(0.05))
ax.yaxis.set_major_locator(mticker.MultipleLocator(0.1))

ax.grid(True, linestyle=":", color="grey", alpha=0.6)
ax.set_axisbelow(True)

ax.set_xlabel(r"$\gamma$")
ax.set_ylabel("acceptance rate")

ax.tick_params(length=0)

ax.legend(frameon=True, facecolor="white", edgecolor="black")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 2 : Tunning of $l$ via grid search

# %%
@torch.no_grad()
def compute_energy_trajectory(sampler, z_0: torch.Tensor):
    v_0 = sampler.sample_momentum(z_0)
    traj_q, traj_p = sampler.leapfrog(z_0, v_0, return_traj=True)  # (B, l+1, d)
    n_steps = traj_q.shape[1]
    V = torch.stack([sampler.U(traj_q[:, t, :])                   for t in range(n_steps)], dim=1)
    H = torch.stack([sampler.H(traj_q[:, t, :], traj_p[:, t, :]) for t in range(n_steps)], dim=1)
    T = H - V
    return V, T, H




def plot_energy_trajectory(
    sampler_hmc, sampler_rhmc,
    gamma_hmc: float, gamma_rhmc: float,
    z_0: torch.Tensor = torch.zeros(1, STATE_DIM),
):
    U_hmc,  K_hmc,  H_hmc = compute_energy_trajectory(sampler_hmc,  z_0)
    U_rhmc, K_rhmc, H_rhmc = compute_energy_trajectory(sampler_rhmc, z_0)

    for U, K, H, gamma in [
        (U_hmc,  K_hmc,  H_hmc,  gamma_hmc),
        (U_rhmc, K_rhmc, H_rhmc, gamma_rhmc),
    ]:
        fig, ax = plt.subplots(figsize=(6, 5))
        steps = torch.arange(U.shape[1]).float()
        t = gamma * steps
        ax.plot(t, U.mean(0).cpu(), color='#d62728', linewidth=1.5, label=r'$U$')
        ax.plot(t, K.mean(0).cpu(), color='#1f77b4', linewidth=1.5, label=r'$K$')
        ax.plot(t, H.mean(0).cpu(), color='black',   linewidth=1.5, label=r'$H$ (total)')
        ax.set_xlabel(r'integration time $t = \gamma \cdot n$')
        ax.set_ylabel('energy')
        ax.legend(frameon=True, loc='upper right')
        ax.grid(True, linestyle=':', color='grey', alpha=0.6)
        ax.set_axisbelow(True)
        ax.tick_params(length=0)
        plt.tight_layout()
        plt.show()

# %%
gamma_hmc = 0.01
l_traj_hmc = 1000
gamma_rhmc = 0.01
l_traj_rhmc = 1000

mass = 1

sampler_hmc_traj = FunnelHMC(
    dim=DIM, mass = mass, l=l_traj_hmc, gamma=gamma_hmc, N_run=1, skip_acceptance=True,
)
sampler_rhmc_traj = FunnelRHMC(
    dim=DIM, l=l_traj_rhmc, N_fx=6, gamma=gamma_rhmc, N_run=1, skip_acceptance=True,
)

plot_energy_trajectory(
    sampler_hmc_traj, sampler_rhmc_traj,
    gamma_hmc=gamma_hmc, gamma_rhmc=gamma_rhmc,
    z_0=torch.zeros(1, STATE_DIM),
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 15
#       8 sampler_hmc_traj = FunnelHMC(
#       9     dim=DIM, mass = mass, l=l_traj_hmc, gamma=gamma_hmc, N_run=1, skip_acceptance=True,
#      10 )
#      11 sampler_rhmc_traj = FunnelRHMC(
#      12     dim=DIM, l=l_traj_rhmc, N_fx=6, gamma=gamma_rhmc, N_run=1, skip_acceptance=True,
#      13 )
# ---> 15 plot_energy_trajectory(
#      16     sampler_hmc_traj, sampler_rhmc_traj,
#      17     gamma_hmc=gamma_hmc, gamma_rhmc=gamma_rhmc,
#      18     z_0=torch.zeros(1, STATE_DIM),
#      19 )
#
# Cell In[8], line 20, in plot_energy_trajectory(sampler_hmc, sampler_rhmc, gamma_hmc, gamma_rhmc, z_0)
#      14 def plot_energy_trajectory(
#      15     sampler_hmc, sampler_rhmc,
#      16     gamma_hmc: float, gamma_rhmc: float,
#      17     z_0: torch.Tensor = torch.zeros(1, STATE_DIM),
#      18 ):
#      19     U_hmc,  K_hmc,  H_hmc = compute_energy_trajectory(sampler_hmc,  z_0)
# ---> 20     U_rhmc, K_rhmc, H_rhmc = compute_energy_trajectory(sampler_rhmc, z_0)
#      22     for U, K, H, gamma in [
#      23         (U_hmc,  K_hmc,  H_hmc,  gamma_hmc),
#      24         (U_rhmc, K_rhmc, H_rhmc, gamma_rhmc),
#      25     ]:
#      26         fig, ax = plt.subplots(figsize=(6, 5))
#
# File /opt/homebrew/anaconda3/envs/geodesic_toolbox_bis/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# Cell In[8], line 4, in compute_energy_trajectory(sampler, z_0)
#       1 @torch.no_grad()
#       2 def compute_energy_trajectory(sampler, z_0: torch.Tensor):
#       3     v_0 = sampler.sample_momentum(z_0)
# ----> 4     traj_q, traj_p = sampler.leapfrog(z_0, v_0, return_traj=True)  # (B, l+1, d)
#       5     n_steps = traj_q.shape[1]
#       6     V = torch.stack([sampler.U(traj_q[:, t, :])                   for t in range(n_steps)], dim=1)
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/samplers.py:1182, in ImplicitRHMCSampler.leapfrog(self, z, v, return_traj)
#    1180 beta_k_minus_1_sqrt = self.beta_0_sqrt
#    1181 for k in range(self.l):
# -> 1182     z_new, v_new = self.leapfrog_step(z_new, v_new)
#    1183     beta_k_sqrt = self.tempering(k)
#    1184     v_new = (beta_k_minus_1_sqrt / beta_k_sqrt) * v_new
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/samplers.py:1082, in ImplicitRHMCSampler.leapfrog_step(self, z, v)
#    1064 """
#    1065 Perform a single leapfrog step.
#    1066
#    (...)   1079     The new velocity.
#    1080 """
#    1081 v_half = self.get_v_half(z, v)
# -> 1082 z_new = self.get_z_new(z, v_half)
#    1083 v_new = v_half - self.gamma * self.dH_dz(z_new, v_half) / 2
#    1084 return z_new, v_new
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/samplers.py:1052, in ImplicitRHMCSampler.get_z_new(self, z, v_half)
#    1035 """
#    1036 Solves the fixed point equation for the position.
#    1037 z_new = z + gamma/2 * ( dH_dv(z, v_half) + dH_dv(z_new,v_half) )
#    (...)   1049     The new position.
#    1050 """
#    1051 z_new = z.clone()
# -> 1052 dH_dv = self.dH_dv(z, v_half)
#    1053 for k in range(self.N_fx):
#    1054     z_new_ = (
#    1055         z + self.gamma * (dH_dv + self.dH_dv(z_new, v_half)) / 2
#    1056     )
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/samplers.py:952, in ImplicitRHMCSampler.__init__.<locals>.<lambda>(z, v)
#     950 self._dH_dv = torch.vmap(torch.func.jacrev(no_batch_H, argnums=1))
#     951 self.dH_dz = lambda z, v: self._dH_dz(z, v).squeeze(1)
# --> 952 self.dH_dv = lambda z, v: self._dH_dv(z, v).squeeze(1)
#     954 self.log2pi = torch.log(torch.tensor(2 * 3.1415927410125732))
#
# File /opt/homebrew/anaconda3/envs/geodesic_toolbox_bis/lib/python3.12/site-packages/torch/_functorch/apis.py:208, in vmap.<locals>.wrapped(*args, **kwargs)
#     207 def wrapped(*args, **kwargs):
# --> 208     return vmap_impl(
#     209         func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     210     )
#
# File /opt/homebrew/anaconda3/envs/geodesic_toolbox_bis/lib/python3.12/site-packages/torch/_functorch/vmap.py:283, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     272     return _chunked_vmap(
#     273         func,
#     274         flat_in_dims,
#    (...)    279         **kwargs,
#     280     )
#     282 # If chunk_size is not specified.
# --> 283 return _flat_vmap(
#     284     func,
#     285     batch_size,
#     286     flat_in_dims,
#     287     flat_args,
#     288     args_spec,
#     289     out_dims,
#     290     randomness,
#     291     **kwargs,
#     292 )
#
# File /opt/homebrew/anaconda3/envs/geodesic_toolbox_bis/lib/python3.12/site-packages/torch/_functorch/vmap.py:433, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     429 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     430     batched_inputs = _create_batched_inputs(
#     431         flat_in_dims, flat_args, vmap_level, args_spec
#     432     )
# --> 433     batched_outputs = func(*batched_inputs, **kwargs)
#     434     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File /opt/homebrew/anaconda3/envs/geodesic_toolbox_bis/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:571, in jacrev.<locals>.wrapper_fn(*args)
#     568 @wraps(func)
#     569 def wrapper_fn(*args):
#     570     error_if_complex("jacrev", args, is_input=True)
# --> 571     vjp_out = _vjp_with_argnums(func, *args, argnums=argnums, has_aux=has_aux)
#     572     if has_aux:
#     573         output, vjp_fn, aux = vjp_out
#
# File /opt/homebrew/anaconda3/envs/geodesic_toolbox_bis/lib/python3.12/site-packages/torch/_functorch/vmap.py:48, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      45 @functools.wraps(f)
#      46 def fn(*args, **kwargs):
#      47     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 48         return f(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/geodesic_toolbox_bis/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:359, in _vjp_with_argnums(func, argnums, has_aux, *primals)
#     357     diff_primals = _slice_argnums(primals, argnums, as_tuple=False)
#     358     tree_map_(partial(_create_differentiable, level=level), diff_primals)
# --> 359 primals_out = func(*primals)
#     361 if has_aux:
#     362     if not (isinstance(primals_out, tuple) and len(primals_out) == 2):
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/samplers.py:948, in ImplicitRHMCSampler.__init__.<locals>.<lambda>(x, y)
#     945 self._grad_U = torch.vmap(torch.func.jacrev(no_batch_U))
#     946 self.grad_U = lambda z: self._grad_U(z).squeeze(1)
# --> 948 no_batch_H = lambda x, y: self.H(x.unsqueeze(0), y.unsqueeze(0)).squeeze(0)
#     949 self._dH_dz = torch.vmap(torch.func.jacrev(no_batch_H, argnums=0))
#     950 self._dH_dv = torch.vmap(torch.func.jacrev(no_batch_H, argnums=1))
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/samplers.py:1006, in ImplicitRHMCSampler.H(self, z, v)
#     991 def H(self, z: Tensor, v: Tensor) -> Tensor:
#     992     """
#     993     Compute the Hamiltonian H(z,v) = U(z) + K(v)
#     994
#    (...)   1004     Tensor (b,)
#    1005     """
# -> 1006     return self.U(z) + self.K(v, z)
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/samplers.py:988, in ImplicitRHMCSampler.K(self, v, q)
#     972 """
#     973 Compute the kinetic energy K(v) = - N(v ;0, g(z))
#     974 ie K(v) = 1/2 * v^T g_inv(z) v - 1/2 * log(det(g_inv(z)))
#    (...)    985 kinetic energy : Tensor (b,)
#     986 """
#     987 logdet_ginv = self.cometric.inv_logdet(q)
# --> 988 velocity = self.cometric.cometric(q, v)
#     989 return 0.5 * velocity - 0.5 * logdet_ginv + 0.5 * v.shape[1] * self.log2pi
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/cometric.py:303, in CoMetric.cometric(self, q, v)
#     288 def cometric(self, q: Tensor, v: Tensor) -> Tensor:
#     289     """
#     290     Computes v^T G_inv(q) v for a batch of points q at momenta v
#     291
#    (...)    301         v^T G_inv(q) v
#     302     """
# --> 303     return self.inv_dot(q, v, v)
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/cometric.py:265, in CoMetric.inv_dot(self, q, u, v)
#     248 def inv_dot(self, q: Tensor, u: Tensor, v: Tensor) -> Tensor:
#     249     """
#     250     Computes u^T G_inv(q) v for a batch of points q at tangent vectors u and v
#     251
#    (...)    263         u^T G_inv(q) v
#     264     """
# --> 265     G_inv = self.cometric_tensor(q)
#     266     if self.is_diag:
#     267         return torch.sum(u * G_inv * v, dim=1)
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/cometric.py:202, in CoMetric.cometric_tensor(self, q)
#     187 def cometric_tensor(self, q: Tensor) -> Tensor:
#     188     """
#     189     Computes G^-1(q) for a batch of points q
#     190
#    (...)    200         or Tensor (b, d) if is_diag is True
#     201     """
# --> 202     return self.forward(q)
#
# File ~/Documents/Cours/ARIA/stage/geodesic_toolbox/src/geodesic_toolbox/cometric.py:2712, in FunnelSoftAbs.forward(self, q)
#    2706 alpha_lam = self.alpha * lam
#    2707 cometric_eigs = torch.where(
#    2708     lam.abs() > 1e-8,
#    2709     torch.tanh(alpha_lam) / lam,
#    2710     torch.full_like(lam, self.alpha),
#    2711 )
# -> 2712 return torch.einsum("bij,bj,bkj->bik", Phi, cometric_eigs, Phi)
#
# File /opt/homebrew/anaconda3/envs/geodesic_toolbox_bis/lib/python3.12/site-packages/torch/functional.py:383, in einsum(*args)
#     381     # flatten path for dispatching to C++
#     382     path = [*itertools.chain.from_iterable(tupled_path)]
# --> 383 return _VF.einsum(equation, operands, path=path)
#
# KeyboardInterrupt:

# %% [markdown]
# Fill in after inspecting the plots above (mirroring the Rosenbrock notebook's conclusion cell), e.g.:
# - For HMC : $m = ...$, $l=...$ and $\gamma = ...$
# - For RHMC : $l = ...$ and $\gamma = ...$

# %% [markdown]
# ## Step 3 : Tunning of $\beta$

# %%
def acf(chain, max_lag):
    """Normalized autocorrelation at lags 0..max_lag for a 1D array."""
    chain = chain - chain.mean()
    var = np.var(chain)
    return np.array([
        np.mean(chain[:len(chain) - k] * chain[k:]) / var if k > 0 else 1.0
        for k in range(max_lag + 1)
    ])

def ess_from_chain(chain, max_lag):
    """
    ESS = N / IAT,  IAT = 1 + 2 * sum_{k>=1} ACF(k).
    Sum truncated at the first negative lag (Geyer's initial positive sequence).
    """
    ac = acf(chain, max_lag)
    first_neg = np.argmax(ac[1:] < 0)
    cutoff = first_neg if first_neg > 0 else max_lag
    iat = 1.0 + 2.0 * ac[1:cutoff + 1].sum()
    return len(chain) / max(iat, 1.0)


def gelman_rubin(traj):
    """Split-R_hat per coordinate. traj: (n_chains, n_steps, d) tensor/array."""
    traj = traj.numpy() if hasattr(traj, "numpy") else np.asarray(traj)
    B, N, d = traj.shape
    if B < 2:
        return np.ones(d)
    chain_means = traj.mean(axis=1)
    grand_mean = chain_means.mean(axis=0)
    W = ((traj - chain_means[:, None, :]) ** 2).sum(axis=(0, 1)) / (B * (N - 1))
    B_hat = N / (B - 1) * ((chain_means - grand_mean) ** 2).sum(axis=0)
    var_hat = (N - 1) / N * W + B_hat / N
    return np.sqrt(var_hat / np.clip(W, 1e-10, None))


def central_and_band(per_chain_vec, stat: str = "mean"):
    """Central tendency across chains + STANDARD ERROR band (not raw std).

    per_chain_vec : (grid_res, batch_size)  -- one coordinate's ESS per chain.
    The uncertainty on the *mean* is std/sqrt(batch); that is what should be
    shaded to judge whether a beta-trend is real (raw std is per-chain dispersion
    and makes every beta overlap).
    """
    B = per_chain_vec.shape[1]
    central = np.median(per_chain_vec, axis=1) if stat == "median" else per_chain_vec.mean(axis=1)
    sem = per_chain_vec.std(axis=1, ddof=0) / B ** 0.5
    return central, sem


def per_chain_ess(traj, dim, max_lag):
    """Per-chain ESS for one coordinate, using the same Geyer estimator as above."""
    return np.array([ess_from_chain(traj[i, :, dim].numpy(), max_lag) for i in range(traj.shape[0])])

# %%
import os
from concurrent.futures import ProcessPoolExecutor, as_completed

import tqdm

from funnel_beta_worker import eval_beta_traj

l = 10
gamma = 0.1
N_run = 100
n_traj = 50
d = STATE_DIM
seed = None

z_0_beta = torch.zeros(n_traj, STATE_DIM)
max_lag = 100
# beta=1 sits exactly on the Randers dual cometric's convexity boundary
# (alpha = 1 - beta^2 * sigmoid(||grad U||_G)^2 -> 0 wherever the gradient is
# large), so omega_star/G_star blow up there, acceptance collapses to ~0,
# chains freeze, and ESS/R_hat become numerically meaningless. Stop at 0.9.
betas = np.linspace(0.0, 0.9, 10)

# Per-chain, per-coordinate ESS for each beta: shape (len(betas), n_traj, d).
evals_full    = np.zeros((len(betas), n_traj, d))   # reduced_flip = False
evals_reduced = np.zeros((len(betas), n_traj, d))   # reduced_flip = True
acc_full,  acc_reduced  = np.zeros(len(betas)), np.zeros(len(betas))
# Per-coordinate split-R_hat across chains for each beta: shape (len(betas), d).
rhat_full    = np.zeros((len(betas), d))
rhat_reduced = np.zeros((len(betas), d))

# One worker process per (beta, flip-variant) job, capped by the number of
# cores; each worker stays single-threaded so the processes don't
# oversubscribe the CPU.
n_workers = min(os.cpu_count(), 2 * len(betas))

jobs = {}
with ProcessPoolExecutor(max_workers=n_workers) as executor:
    for i, beta in enumerate(betas):
        jobs[executor.submit(eval_beta_traj, beta, gamma, l, False, DIM, N_run, n_traj, z_0_beta, 1, seed)] = (i, "full")
        jobs[executor.submit(eval_beta_traj, beta, gamma, l, True,  DIM, N_run, n_traj, z_0_beta, 1, seed)] = (i, "reduced")

    for future in tqdm.tqdm(as_completed(jobs), total=len(jobs)):
        i, kind = jobs[future]
        traj_beta, acc, flip = future.result()
        # ESS is reported for v (dim 0) and one representative theta coordinate (dim 1).
        ess_v  = per_chain_ess(traj_beta, dim=0, max_lag=max_lag)
        ess_th = per_chain_ess(traj_beta, dim=1, max_lag=max_lag)
        rhat = gelman_rubin(traj_beta)
        if kind == "full":
            evals_full[i, :, 0], evals_full[i, :, 1] = ess_v, ess_th
            acc_full[i] = acc
            rhat_full[i] = rhat
        else:
            evals_reduced[i, :, 0], evals_reduced[i, :, 1] = ess_v, ess_th
            acc_reduced[i] = acc
            rhat_reduced[i] = rhat
# Out:
#  50%|█████     | 10/20 [17:21<28:21, 170.19s/it] /var/folders/gh/sw58v_0x4wd_8ktr762xffzh0000gn/T/ipykernel_30672/414852428.py:6: RuntimeWarning: invalid value encountered in scalar divide
#   np.mean(chain[:len(chain) - k] * chain[k:]) / var if k > 0 else 1.0
# 100%|██████████| 20/20 [28:32<00:00, 85.63s/it]

# %%
color_full, color_reduced = "#1f77b4", "#d62728"
coord_names = ["v", "theta_1"]

n_dims = 2  # only plot v and theta_1

fig, axes = plt.subplots(1, n_dims, figsize=(13, 5), sharex=True)

for dim, ax in enumerate(axes):
    for mat, color, label in [
        (evals_full[..., dim],    color_full,    "FHMC"),
        (evals_reduced[..., dim], color_reduced, "FHMC (reduced flips)"),
    ]:
        central, sem = central_and_band(mat, stat="mean")
        ax.plot(
            betas,
            central,
            label=label,
            color=color,
            linewidth=2,
            marker="o",
            markersize=4,
        )
        ax.fill_between(
            betas,
            central - sem,
            central + sem,
            color=color,
            alpha=0.2,
        )

    ax.axvline(0.0, color="grey", linestyle="--", linewidth=1, alpha=0.6)
    ax.grid(True, linestyle=":", color="grey", alpha=0.6)
    ax.set_axisbelow(True)
    ax.set_xlabel(r"$\beta$")
    ax.set_title(f"ESS along {coord_names[dim]}")
    ax.tick_params(length=0)

axes[0].set_ylabel(r"ESS (mean over chains)")
axes[0].text(
    0.01,
    axes[0].get_ylim()[1],
    r"$\beta=0$ is RHMC",
    va="top",
    fontsize=9,
    color="grey",
)
axes[0].legend(frameon=True)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 5))

ax.plot(betas, acc_full, label="FHMC", color=color_full, linewidth=2, marker="o", markersize=4)
ax.plot(betas, acc_reduced, label="FHMC (reduced flips)", color=color_reduced, linewidth=2, marker="o", markersize=4)

# beta = 0 is RHMC.
ax.axvline(0.0, color="grey", linestyle="--", linewidth=1, alpha=0.6)

ax.grid(True, linestyle=":", color="grey", alpha=0.6)
ax.set_axisbelow(True)
ax.set_xlabel(r"$\beta$")
ax.set_ylabel("acceptance rate")
ax.set_title(r"$\beta=0$ is RHMC", fontsize=9, color="grey", loc="left")
ax.tick_params(length=0)
ax.legend(frameon=True)

plt.tight_layout()
plt.show()

# %%
# Only the two coordinates tracked above (v, theta_1); rhat_full/rhat_reduced
# hold all STATE_DIM coordinates, but plotting all of them would be unwieldy.
plot_dims = [0, 1]
fig, axes = plt.subplots(1, len(plot_dims), figsize=(13, 5), sharex=True)

for ax, dim in zip(axes, plot_dims):
    for mat, color, label in [
        (rhat_full[:, dim],    color_full,    "FHMC"),
        (rhat_reduced[:, dim], color_reduced, "FHMC (reduced flips)"),
    ]:
        ax.plot(betas, mat, label=label, color=color, linewidth=2, marker="o", markersize=4)

    # beta = 0 is RHMC.
    ax.axvline(0.0, color="grey", linestyle="--", linewidth=1, alpha=0.6)
    ax.axhline(1.0, color="black", linestyle=":", linewidth=1, alpha=0.6)

    ax.grid(True, linestyle=":", color="grey", alpha=0.6)
    ax.set_axisbelow(True)
    ax.set_xlabel(r"$\beta$")
    ax.set_title(f"$\\hat R$ along {coord_names[dim]}")
    ax.tick_params(length=0)

axes[0].set_ylabel(r"$\hat R$")
axes[0].text(0.01, axes[0].get_ylim()[1], r"$\beta=0$ is RHMC", va="top", fontsize=9, color="grey")
axes[0].legend(frameon=True)

plt.tight_layout()
plt.show()
